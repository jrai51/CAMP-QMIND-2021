# %% [markdown]
# # Camp QMIND Intro Hackathon - Titanic Survival Prediction

# %% [markdown]
# Import relevant libraries and packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %% [markdown]
# Read in train and test data

# %%
df_train = pd.read_csv('titanic_train.csv') # reading train data into "df_train"
df_test = pd.read_csv('titanic_test.csv') # reading test data into "df_test"

# %% [markdown]
# Inspect the training dataset

# %%
df_train.head(50) # print the first 10 rows of the training set
# Out:
#     PassengerId  Survived  Pclass  \
# 0           294         0       3
# 1           398         0       2
# 2           384         1       1
# 3           133         0       3
# 4           267         0       3
# 5           628         1       1
# 6           192         0       2
# 7           866         1       2
# 8           641         0       3
# 9           826         0       3
# 10          686         0       2
# 11          467         0       2
# 12          580         1       3
# 13          856         1       3
# 14          170         0       3
# 15          151         0       2
# 16          650         1       3
# 17          683         0       3
# 18          180         0       3
# 19          600         1       1
# 20          140         0       1
# 21           37         1       3
# 22          656         0       2
# 23          587         0       2
# 24          842         0       2
# 25          343         0       2
# 26          401         1       3
# 27          704         0       3
# 28          831         1       3
# 29          370         1       1
# 30           20         1       3
# 31          127         0       3
# 32          594         0       3
# 33            6         0       3
# 34          487         1       1
# 35          807         0       1
# 36          421         0       3
# 37          712         0       1
# 38          235         0       2
# 39          174         0       3
# 40          204         0       3
# 41          621         0       3
# 42          378         0       1
# 43          325         0       3
# 44           25         0       3
# 45          726         0       3
# 46          419         0       2
# 47          563         0       2
# 48          865         0       2
# 49          734         0       2
#
#                                                  Name     Sex   Age  SibSp  \
# 0                                 Haas, Miss. Aloisia  female  24.0      0
# 1                             McKane, Mr. Peter David    male  46.0      0
# 2   Holverson, Mrs. Alexander Oskar (Mary Aline To...  female  35.0      1
# 3      Robins, Mrs. Alexander A (Grace Charity Laury)  female  47.0      1
# 4                           Panula, Mr. Ernesti Arvid    male  16.0      4
# 5                       Longley, Miss. Gretchen Fiske  female  21.0      0
# 6                               Carbines, Mr. William    male  19.0      0
# 7                            Bystrom, Mrs. (Karolina)  female  42.0      0
# 8                              Jensen, Mr. Hans Peder    male  20.0      0
# 9                                     Flynn, Mr. John    male   NaN      0
# 10             Laroche, Mr. Joseph Philippe Lemercier    male  25.0      1
# 11                              Campbell, Mr. William    male   NaN      0
# 12                                Jussila, Mr. Eiriik    male  32.0      0
# 13                         Aks, Mrs. Sam (Leah Rosen)  female  18.0      0
# 14                                      Ling, Mr. Lee    male  28.0      0
# 15                         Bateman, Rev. Robert James    male  51.0      0
# 16                    Stanley, Miss. Amy Zillah Elsie  female  23.0      0
# 17                        Olsvigen, Mr. Thor Anderson    male  20.0      0
# 18                                Leonard, Mr. Lionel    male  36.0      0
# 19       Duff Gordon, Sir. Cosmo Edmund ("Mr Morgan")    male  49.0      1
# 20                                 Giglio, Mr. Victor    male  24.0      0
# 21                                   Mamee, Mr. Hanna    male   NaN      0
# 22                          Hickman, Mr. Leonard Mark    male  24.0      2
# 23                            Jarvis, Mr. John Denzil    male  47.0      0
# 24                           Mudd, Mr. Thomas Charles    male  16.0      0
# 25                         Collander, Mr. Erik Gustaf    male  28.0      0
# 26                                 Niskanen, Mr. Juha    male  39.0      0
# 27                              Gallagher, Mr. Martin    male  25.0      0
# 28            Yasbeck, Mrs. Antoni (Selini Alexander)  female  15.0      1
# 29                      Aubart, Mme. Leontine Pauline  female  24.0      0
# 30                            Masselmani, Mrs. Fatima  female   NaN      0
# 31                                McMahon, Mr. Martin    male   NaN      0
# 32                                 Bourke, Miss. Mary  female   NaN      0
# 33                                   Moran, Mr. James    male   NaN      0
# 34    Hoyt, Mrs. Frederick Maxfield (Jane Anne Forby)  female  35.0      1
# 35                             Andrews, Mr. Thomas Jr    male  39.0      0
# 36                             Gheorgheff, Mr. Stanio    male   NaN      0
# 37                                 Klaber, Mr. Herman    male   NaN      0
# 38                  Leyson, Mr. Robert William Norman    male  24.0      0
# 39                          Sivola, Mr. Antti Wilhelm    male  21.0      0
# 40                               Youseff, Mr. Gerious    male  45.5      0
# 41                                Yasbeck, Mr. Antoni    male  27.0      1
# 42                          Widener, Mr. Harry Elkins    male  27.0      0
# 43                           Sage, Mr. George John Jr    male   NaN      8
# 44                      Palsson, Miss. Torborg Danira  female   8.0      3
# 45                                Oreskovic, Mr. Luka    male  20.0      0
# 46                         Matthews, Mr. William John    male  30.0      0
# 47                         Norman, Mr. Robert Douglas    male  28.0      0
# 48                             Gill, Mr. John William    male  24.0      0
# 49                         Berriman, Mr. William John    male  23.0      0
#
#     Parch             Ticket      Fare Cabin Embarked
# 0       0             349236    8.8500   NaN        S
# 1       0              28403   26.0000   NaN        S
# 2       0             113789   52.0000   NaN        S
# 3       0          A/5. 3337   14.5000   NaN        S
# 4       1            3101295   39.6875   NaN        S
# 5       0              13502   77.9583    D9        S
# 6       0              28424   13.0000   NaN        S
# 7       0             236852   13.0000   NaN        S
# 8       0             350050    7.8542   NaN        S
# 9       0             368323    6.9500   NaN        Q
# 10      2      SC/Paris 2123   41.5792   NaN        C
# 11      0             239853    0.0000   NaN        S
# 12      0  STON/O 2. 3101286    7.9250   NaN        S
# 13      1             392091    9.3500   NaN        S
# 14      0               1601   56.4958   NaN        S
# 15      0        S.O.P. 1166   12.5250   NaN        S
# 16      0           CA. 2314    7.5500   NaN        S
# 17      0               6563    9.2250   NaN        S
# 18      0               LINE    0.0000   NaN        S
# 19      0           PC 17485   56.9292   A20        C
# 20      0           PC 17593   79.2000   B86        C
# 21      0               2677    7.2292   NaN        C
# 22      0       S.O.C. 14879   73.5000   NaN        S
# 23      0             237565   15.0000   NaN        S
# 24      0        S.O./P.P. 3   10.5000   NaN        S
# 25      0             248740   13.0000   NaN        S
# 26      0  STON/O 2. 3101289    7.9250   NaN        S
# 27      0              36864    7.7417   NaN        Q
# 28      0               2659   14.4542   NaN        C
# 29      0           PC 17477   69.3000   B35        C
# 30      0               2649    7.2250   NaN        C
# 31      0             370372    7.7500   NaN        Q
# 32      2             364848    7.7500   NaN        Q
# 33      0             330877    8.4583   NaN        Q
# 34      0              19943   90.0000   C93        S
# 35      0             112050    0.0000   A36        S
# 36      0             349254    7.8958   NaN        C
# 37      0             113028   26.5500  C124        S
# 38      0         C.A. 29566   10.5000   NaN        S
# 39      0  STON/O 2. 3101280    7.9250   NaN        S
# 40      0               2628    7.2250   NaN        C
# 41      0               2659   14.4542   NaN        C
# 42      2             113503  211.5000   C82        C
# 43      2           CA. 2343   69.5500   NaN        S
# 44      1             349909   21.0750   NaN        S
# 45      0             315094    8.6625   NaN        S
# 46      0              28228   13.0000   NaN        S
# 47      0             218629   13.5000   NaN        S
# 48      0             233866   13.0000   NaN        S
# 49      0              28425   13.0000   NaN        S

# %%
df_train.shape # print the number of rows and columns in the training set
# Out:
# (711, 12)

# %%
df_train.columns # print column names for training set
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df_train.describe() # statistical summary of training dataset columns
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   711.000000  711.000000  711.000000  560.000000  711.000000
# mean    452.794655    0.375527    2.298172   30.093161    0.510549
# std     257.314342    0.484600    0.836481   14.362382    1.108019
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     237.500000    0.000000    2.000000   21.000000    0.000000
# 50%     454.000000    0.000000    3.000000   29.000000    0.000000
# 75%     670.500000    1.000000    3.000000   39.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  711.000000  711.000000
# mean     0.368495   31.886409
# std      0.806186   47.859701
# min      0.000000    0.000000
# 25%      0.000000    7.925000
# 50%      0.000000   14.454200
# 75%      0.000000   30.695800
# max      6.000000  512.329200

# %%
df_train.isnull().sum() # print the number of null values in each column of the training dataset
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            151
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          549
# Embarked         1
# dtype: int64

# %% [markdown]
# Inspect the test dataset

# %%
df_test.head(50) # print the first 10 rows of the test set
# Out:
#     PassengerId  Pclass                                               Name  \
# 0           680       1                 Cardeza, Mr. Thomas Drake Martinez
# 1           357       1                        Bowerman, Miss. Elsie Edith
# 2           753       3                   Vande Velde, Mr. Johannes Joseph
# 3           123       2                               Nasser, Mr. Nicholas
# 4           169       1                                Baumann, Mr. John D
# 5           495       3                         Stanley, Mr. Edward Roland
# 6            96       3                        Shorney, Mr. Charles Joseph
# 7           444       2                          Reynaldo, Ms. Encarnacion
# 8           703       3                              Barbara, Miss. Saiide
# 9           713       1                           Taylor, Mr. Elmer Zebley
# 10          481       3                     Goodwin, Master. Harold Victor
# 11          651       3                                  Mitkoff, Mr. Mito
# 12          591       3                               Rintamaki, Mr. Matti
# 13          821       1  Hays, Mrs. Charles Melville (Clara Jennings Gr...
# 14          790       1                           Guggenheim, Mr. Benjamin
# 15          115       3                              Attalah, Miss. Malake
# 16           13       3                     Saundercock, Mr. William Henry
# 17          551       1                        Thayer, Mr. John Borland Jr
# 18          425       3                        Rosblom, Mr. Viktor Richard
# 19          277       3                  Lindblom, Miss. Augusta Charlotta
# 20          578       1          Silvey, Mrs. William Baird (Alice Munger)
# 21          479       3                          Karlsson, Mr. Nils August
# 22          434       3                         Kallio, Mr. Nikolai Erland
# 23          205       3                           Cohen, Mr. Gurshon "Gus"
# 24          729       2                    Bryhl, Mr. Kurt Arnold Gottfrid
# 25          195       1          Brown, Mrs. James Joseph (Margaret Tobin)
# 26          394       1                             Newell, Miss. Marjorie
# 27          694       3                                   Saad, Mr. Khalil
# 28          165       3                       Panula, Master. Eino Viljami
# 29          748       2                              Sinkkonen, Miss. Anna
# 30          531       2                           Quick, Miss. Phyllis May
# 31           30       3                                Todoroff, Mr. Lalio
# 32          747       3                        Abbott, Mr. Rossmore Edward
# 33          695       1                                    Weir, Col. John
# 34          607       3                                  Karaic, Mr. Milan
# 35           98       1                    Greenfield, Mr. William Bertram
# 36          340       1                       Blackwell, Mr. Stephen Weart
# 37          233       2                          Sjostedt, Mr. Ernst Adolf
# 38          352       1             Williams-Lambert, Mr. Fletcher Fellows
# 39          867       2                       Duran y More, Miss. Asuncion
# 40          112       3                               Zabour, Miss. Hileni
# 41          120       3                  Andersson, Miss. Ellis Anna Maria
# 42          475       3                        Strandberg, Miss. Ida Sofia
# 43          372       3                          Wiklund, Mr. Jakob Alfred
# 44          146       2                       Nicholls, Mr. Joseph Charles
# 45           50       3      Arnold-Franchi, Mrs. Josef (Josefine Franchi)
# 46           11       3                    Sandstrom, Miss. Marguerite Rut
# 47          549       3                          Goldsmith, Mr. Frank John
# 48          574       3                                  Kelly, Miss. Mary
# 49          786       3                 Harmer, Mr. Abraham (David Lishin)
#
#        Sex   Age  SibSp  Parch             Ticket      Fare        Cabin  \
# 0     male  36.0      0      1           PC 17755  512.3292  B51 B53 B55
# 1   female  22.0      0      1             113505   55.0000          E33
# 2     male  33.0      0      0             345780    9.5000          NaN
# 3     male  32.5      1      0             237736   30.0708          NaN
# 4     male   NaN      0      0           PC 17318   25.9250          NaN
# 5     male  21.0      0      0          A/4 45380    8.0500          NaN
# 6     male   NaN      0      0             374910    8.0500          NaN
# 7   female  28.0      0      0             230434   13.0000          NaN
# 8   female  18.0      0      1               2691   14.4542          NaN
# 9     male  48.0      1      0              19996   52.0000         C126
# 10    male   9.0      5      2            CA 2144   46.9000          NaN
# 11    male   NaN      0      0             349221    7.8958          NaN
# 12    male  35.0      0      0  STON/O 2. 3101273    7.1250          NaN
# 13  female  52.0      1      1              12749   93.5000          B69
# 14    male  46.0      0      0           PC 17593   79.2000      B82 B84
# 15  female  17.0      0      0               2627   14.4583          NaN
# 16    male  20.0      0      0          A/5. 2151    8.0500          NaN
# 17    male  17.0      0      2              17421  110.8833          C70
# 18    male  18.0      1      1             370129   20.2125          NaN
# 19  female  45.0      0      0             347073    7.7500          NaN
# 20  female  39.0      1      0              13507   55.9000          E44
# 21    male  22.0      0      0             350060    7.5208          NaN
# 22    male  17.0      0      0  STON/O 2. 3101274    7.1250          NaN
# 23    male  18.0      0      0           A/5 3540    8.0500          NaN
# 24    male  25.0      1      0             236853   26.0000          NaN
# 25  female  44.0      0      0           PC 17610   27.7208           B4
# 26  female  23.0      1      0              35273  113.2750          D36
# 27    male  25.0      0      0               2672    7.2250          NaN
# 28    male   1.0      4      1            3101295   39.6875          NaN
# 29  female  30.0      0      0             250648   13.0000          NaN
# 30  female   2.0      1      1              26360   26.0000          NaN
# 31    male   NaN      0      0             349216    7.8958          NaN
# 32    male  16.0      1      1          C.A. 2673   20.2500          NaN
# 33    male  60.0      0      0             113800   26.5500          NaN
# 34    male  30.0      0      0             349246    7.8958          NaN
# 35    male  23.0      0      1           PC 17759   63.3583      D10 D12
# 36    male  45.0      0      0             113784   35.5000            T
# 37    male  59.0      0      0             237442   13.5000          NaN
# 38    male   NaN      0      0             113510   35.0000         C128
# 39  female  27.0      1      0      SC/PARIS 2149   13.8583          NaN
# 40  female  14.5      1      0               2665   14.4542          NaN
# 41  female   2.0      4      2             347082   31.2750          NaN
# 42  female  22.0      0      0               7553    9.8375          NaN
# 43    male  18.0      1      0            3101267    6.4958          NaN
# 44    male  19.0      1      1         C.A. 33112   36.7500          NaN
# 45  female  18.0      1      0             349237   17.8000          NaN
# 46  female   4.0      1      1            PP 9549   16.7000           G6
# 47    male  33.0      1      1             363291   20.5250          NaN
# 48  female   NaN      0      0              14312    7.7500          NaN
# 49    male  25.0      0      0             374887    7.2500          NaN
#
#    Embarked
# 0         C
# 1         S
# 2         S
# 3         C
# 4         S
# 5         S
# 6         S
# 7         S
# 8         C
# 9         S
# 10        S
# 11        S
# 12        S
# 13        S
# 14        C
# 15        C
# 16        S
# 17        C
# 18        S
# 19        S
# 20        S
# 21        S
# 22        S
# 23        S
# 24        S
# 25        C
# 26        C
# 27        C
# 28        S
# 29        S
# 30        S
# 31        S
# 32        S
# 33        S
# 34        S
# 35        C
# 36        S
# 37        S
# 38        S
# 39        C
# 40        C
# 41        S
# 42        S
# 43        S
# 44        S
# 45        S
# 46        S
# 47        S
# 48        Q
# 49        S

# %%
df_test.shape # print the number of rows and columns in the test set
# Out:
# (180, 11)

# %%
df_test.columns # print column names for test set (*NOTE: there is no 'Survived' column in this dataset, since this is what YOU must predict)
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df_test.describe() # statistical summary of test dataset columns
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   180.000000  180.000000  154.000000  180.000000  180.000000  180.000000
# mean    419.161111    2.350000   28.266234    0.572222    0.433333   33.459514
# std     256.464252    0.835491   15.069357    1.083294    0.805706   56.487116
# min       3.000000    1.000000    1.000000    0.000000    0.000000    0.000000
# 25%     194.000000    2.000000   18.000000    0.000000    0.000000    7.895800
# 50%     426.000000    3.000000   25.500000    0.000000    0.000000   14.454200
# 75%     653.500000    3.000000   35.750000    1.000000    1.000000   31.387500
# max     867.000000    3.000000   71.000000    5.000000    5.000000  512.329200

# %%
df_test.isnull().sum() # print the number of null values in each column of the test dataset
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             26
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          138
# Embarked         1
# dtype: int64

# %% [markdown]
# Perform some data visualization to further inspect the train data

# %%
plt.hist(df_train['Fare'] * df_train['Survived'])
plt.show()

plt.hist(df_train['Fare'])
plt.show()

sns.boxenplot(x='Survived', y='Age', data=df_train) # likelyhood of survival based on embarked point

#sns.barplot(x='Sex', y='Survived', data=df_train) # likelyhood of survival based on gender
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Age'>

# %%
sns.barplot(x='SibSp', y='Survived', data=df_train) # likelyhood of survival based on gender
# Out:
# <AxesSubplot:xlabel='SibSp', ylabel='Survived'>

# %%
df_train['Age']
# Out:
# 0      24.0
# 1      46.0
# 2      35.0
# 3      47.0
# 4      16.0
#        ...
# 706    35.0
# 707     NaN
# 708    28.0
# 709    45.0
# 710     NaN
# Name: Age, Length: 711, dtype: float64

# %% [markdown]
# Data cleaning and feature engineering

# %%
df_train.drop(columns=['PassengerId', 'Name', 'Cabin', 'Ticket', 'Fare'])

to_drop = [] # Rows to drop.

for index, row in df_train.iterrows():
    age = row['Age']
    if (math.isnan(age)):
        to_drop.append(index)

print('to_drop', to_drop)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-73-265da994b71c> in <module>
#       5 for index, row in df_train.iterrows():
#       6     age = row['Age']
# ----> 7     if (math.isnan(age)):
#       8         to_drop.append(index)
#       9
#
# NameError: name 'math' is not defined

# %% [markdown]
# Train test split

# %% [markdown]
# Build and evaluate model

# %%
# Generate predictions using your model

prediction = MODEL_NAME.predict(x_test) #MAKE SURE TO CHANGE THE MODEL NAME TO WHATEVER MODEL YOU ARE USING

# %% [markdown]
# Submit predictions

# %%
submission = pd.DataFrame({'PassengerId':test['PassengerId'],'Survived':pred})

submit.to_csv('./titanic_submission_group-#.csv',index = False)
